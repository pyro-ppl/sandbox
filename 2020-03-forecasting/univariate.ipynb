# %% [markdown]
# # Univariate Stable parameter estimation

# %%
from collections import defaultdict
import pickle
import numpy as np
from matplotlib import pyplot as plt

# %matplotlib inline

# %%
with open("results/univariate/summary.pkl", "rb") as f:
    summary = pickle.load(f)
print(len(summary))
# Out:
# 6000

# %%
methods = set()
errors = defaultdict(list)
cols = [set() for _ in range(5)]
for r in summary:
    for k, v in r["error"].items():
        key = k, r["name"], r["truth"]["stability"], r["truth"]["skew"], r["num_samples"]
        errors[key].append(v)
        for k, c in zip(key, cols):
            c.add(k)
errors = {k: np.mean(v) for k, v in errors.items()}
cols = [list(sorted(c)) for c in cols]
print(len(errors))
# Out:
# 480

# %%
for k in reversed(cols[0]):
    print("{}".format(k))
    for name in cols[1]:
        print("  {}".format(name))
        for stability in reversed(cols[2]):
            for skew in cols[3]:
                if k == "skew" and skew == 0:
                    continue
                e = []
                for num_samples in cols[4]:
                    e.append(errors[k, name, stability, skew, num_samples])
                print("    {:0.1f} {:0.1f} | {:0.3g} {:0.3g} {:0.3g}"
                      .format(stability, skew, *e))
# Out:
# stability
#   Energy
#     1.9 0.0 | 0.444 0.51 0.423
#     1.9 0.1 | 0.518 0.521 0.426
#     1.9 0.5 | 0.518 0.521 0.425
#     1.9 0.9 | 0.518 0.52 0.425
#     1.7 0.0 | 0.355 0.434 0.368
#     1.7 0.1 | 0.381 0.413 0.315
#     1.7 0.5 | 0.382 0.411 0.314
#     1.7 0.9 | 0.384 0.407 0.312
#     1.5 0.0 | 0.362 0.375 0.302
#     1.5 0.1 | 0.327 0.341 0.28
#     1.5 0.5 | 0.327 0.338 0.278
#     1.5 0.9 | 0.332 0.335 0.276
#     1.0 0.0 | 0.354 0.248 0.217
#     1.0 0.1 | 0.325 0.264 0.248
#     1.0 0.5 | 0.329 0.263 0.248
#     1.0 0.9 | 0.329 0.263 0.243
#     0.5 0.0 | 0.238 0.155 0.0876
#     0.5 0.1 | 0.236 0.167 0.103
#     0.5 0.5 | 0.247 0.165 0.103
#     0.5 0.9 | 0.257 0.159 0.0987
#   SVI
#     1.9 0.0 | 0.0439 0.0204 0.0171
#     1.9 0.1 | 0.0418 0.0192 0.0161
#     1.9 0.5 | 0.0399 0.0185 0.0167
#     1.9 0.9 | 0.0397 0.0176 0.0174
#     1.7 0.0 | 0.101 0.0823 0.0827
#     1.7 0.1 | 0.101 0.0806 0.0813
#     1.7 0.5 | 0.109 0.0823 0.0837
#     1.7 0.9 | 0.112 0.0849 0.09
#     1.5 0.0 | 0.174 0.155 0.153
#     1.5 0.1 | 0.177 0.154 0.152
#     1.5 0.5 | 0.181 0.157 0.157
#     1.5 0.9 | 0.196 0.166 0.169
#     1.0 0.0 | 0.352 0.322 0.312
#     1.0 0.1 | 0.367 0.325 0.316
#     1.0 0.5 | 0.383 0.334 0.327
#     1.0 0.9 | 0.413 0.356 0.351
#     0.5 0.0 | 0.176 0.072 0.0459
#     0.5 0.1 | 0.234 0.122 0.1
#     0.5 0.5 | 0.244 0.139 0.115
#     0.5 0.9 | 0.29 0.171 0.143
# skew
#   Energy
#     1.9 0.1 | 0.357 0.379 0.44
#     1.9 0.5 | 0.638 0.513 0.554
#     1.9 0.9 | 1 0.801 0.814
#     1.7 0.1 | 0.35 0.369 0.438
#     1.7 0.5 | 0.628 0.511 0.552
#     1.7 0.9 | 0.981 0.787 0.8
#     1.5 0.1 | 0.343 0.353 0.436
#     1.5 0.5 | 0.608 0.499 0.551
#     1.5 0.9 | 0.94 0.766 0.796
#     1.0 0.1 | 0.322 0.298 0.31
#     1.0 0.5 | 0.522 0.47 0.464
#     1.0 0.9 | 0.788 0.698 0.753
#     0.5 0.1 | 0.258 0.255 0.232
#     0.5 0.5 | 0.368 0.481 0.465
#     0.5 0.9 | 0.58 0.858 0.887
#   SVI
#     1.9 0.1 | 0.0992 0.0997 0.0999
#     1.9 0.5 | 0.499 0.5 0.5
#     1.9 0.9 | 0.899 0.9 0.9
#     1.7 0.1 | 0.0995 0.0999 0.1
#     1.7 0.5 | 0.5 0.5 0.5
#     1.7 0.9 | 0.9 0.9 0.9
#     1.5 0.1 | 0.0998 0.1 0.1
#     1.5 0.5 | 0.5 0.5 0.5
#     1.5 0.9 | 0.899 0.9 0.9
#     1.0 0.1 | 0.0998 0.1 0.1
#     1.0 0.5 | 0.499 0.5 0.5
#     1.0 0.9 | 0.898 0.9 0.9
#     0.5 0.1 | 0.0996 0.1 0.1
#     0.5 0.5 | 0.498 0.5 0.5
#     0.5 0.9 | 0.897 0.9 0.9
# scale
#   Energy
#     1.9 0.0 | 1.84 19.5 1.02
#     1.9 0.1 | 189 10.3 3.82
#     1.9 0.5 | 189 10.2 3.83
#     1.9 0.9 | 189 10.3 3.82
#     1.7 0.0 | 1.83 19.7 1.18
#     1.7 0.1 | 189 10.4 3.86
#     1.7 0.5 | 189 10.6 3.86
#     1.7 0.9 | 189 10.6 3.87
#     1.5 0.0 | 1.87 20.1 1.44
#     1.5 0.1 | 189 10.8 3.98
#     1.5 0.5 | 189 10.8 4.03
#     1.5 0.9 | 189 10.7 4.03
#     1.0 0.0 | 2.57 22.6 6.42
#     1.0 0.1 | 190 15.5 8.16
#     1.0 0.5 | 190 14.8 8.4
#     1.0 0.9 | 190 14.3 8.78
#     0.5 0.0 | 17.2 123 40.6
#     0.5 0.1 | 239 88.1 71.4
#     0.5 0.5 | 228 101 79.7
#     0.5 0.9 | 210 125 81.1
#   SVI
#     1.9 0.0 | 0.0746 0.0202 0.00663
#     1.9 0.1 | 0.078 0.0223 0.00675
#     1.9 0.5 | 0.0762 0.0222 0.00751
#     1.9 0.9 | 0.0738 0.0215 0.00795
#     1.7 0.0 | 0.0752 0.0303 0.0244
#     1.7 0.1 | 0.0817 0.0328 0.026
#     1.7 0.5 | 0.0848 0.0331 0.0259
#     1.7 0.9 | 0.0832 0.0346 0.0297
#     1.5 0.0 | 0.101 0.0593 0.0621
#     1.5 0.1 | 0.11 0.0629 0.0624
#     1.5 0.5 | 0.112 0.0676 0.0666
#     1.5 0.9 | 0.111 0.0754 0.0762
#     1.0 0.0 | 0.287 0.343 0.353
#     1.0 0.1 | 0.297 0.339 0.345
#     1.0 0.5 | 0.328 0.352 0.361
#     1.0 0.9 | 0.373 0.395 0.4
#     0.5 0.0 | 3.61 10.4 6.67
#     0.5 0.1 | 2.73 4.55 5.02
#     0.5 0.5 | 2.8 4.35 4.95
#     0.5 0.9 | 2.93 4.37 4.98
# loc
#   Energy
#     1.9 0.0 | 3.42 44.2 0.99
#     1.9 0.1 | 666 33.4 11.7
#     1.9 0.5 | 666 33.5 11.7
#     1.9 0.9 | 666 33.5 11.8
#     1.7 0.0 | 3.46 44.2 1
#     1.7 0.1 | 666 33.5 11.7
#     1.7 0.5 | 666 33.6 11.8
#     1.7 0.9 | 666 33.7 12
#     1.5 0.0 | 3.54 44.3 1.03
#     1.5 0.1 | 666 33.7 11.9
#     1.5 0.5 | 666 33.8 12
#     1.5 0.9 | 666 34.1 12.3
#     1.0 0.0 | 4.65 46 2.83
#     1.0 0.1 | 667 35.6 14.3
#     1.0 0.5 | 667 36.3 15.2
#     1.0 0.9 | 668 37.1 16.3
#     0.5 0.0 | 11.1 52.3 10.1
#     0.5 0.1 | 673 41.8 20
#     0.5 0.5 | 674 41.4 20.2
#     0.5 0.9 | 675 41.8 20.3
#   SVI
#     1.9 0.0 | 0.127 0.0337 0.00991
#     1.9 0.1 | 0.126 0.0336 0.0135
#     1.9 0.5 | 0.126 0.0509 0.0471
#     1.9 0.9 | 0.134 0.0819 0.0857
#     1.7 0.0 | 0.129 0.0345 0.0101
#     1.7 0.1 | 0.128 0.0386 0.023
#     1.7 0.5 | 0.147 0.115 0.118
#     1.7 0.9 | 0.203 0.208 0.214
#     1.5 0.0 | 0.125 0.0335 0.0105
#     1.5 0.1 | 0.125 0.0431 0.0335
#     1.5 0.5 | 0.172 0.167 0.172
#     1.5 0.9 | 0.294 0.308 0.315
#     1.0 0.0 | 0.121 0.0378 0.0102
#     1.0 0.1 | 0.119 0.0558 0.0532
#     1.0 0.5 | 0.276 0.273 0.281
#     1.0 0.9 | 0.527 0.528 0.537
#     0.5 0.0 | 0.079 0.0252 0.00971
#     0.5 0.1 | 0.0875 0.0296 0.0198
#     0.5 0.5 | 0.216 0.139 0.133
#     0.5 0.9 | 0.508 0.403 0.379
